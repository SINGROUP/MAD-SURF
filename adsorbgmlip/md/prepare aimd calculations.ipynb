# %%
import numpy as np
import matplotlib.pyplot as plt
import ase
from ase.build import add_adsorbate, fcc111, add_vacuum, bulk
from ase.visualize.plot import plot_atoms
from ase.constraints import FixAtoms
from ase.io import write
from ase.build import molecule
from ase.io import read, write
import json
import os
import glob
import shutil

from ase import Atoms
import pubchempy as pcp
from ase.calculators.vasp import Vasp

# %%
cu_bulk = bulk('Cu')
cu_bulk = cu_bulk.copy().repeat([4, 4, 4])
plot_atoms(cu_bulk)
print(len(cu_bulk))
# Out:
# 64

# %%
write('BULKS/Cu/no_vacancy/geometry.in', cu_bulk)

# %%
## Now we create a random vacancy
cu_one_vacancy = cu_bulk.copy()
i_del = np.random.choice(len(cu_one_vacancy), 1)
del(cu_one_vacancy[i_del])
plot_atoms(cu_one_vacancy)
print(len(cu_one_vacancy))
# Out:
# 63

# %%
write('BULKS/Cu/one_vacancy/geometry.in', cu_one_vacancy)
